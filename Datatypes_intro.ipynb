# %%
name = "lohit"
age = 30
data_trainer = True

# %%
type(name)
# Out:
# str

# %%
type(age)
# Out:
# int

# %%
type(data_trainer)
# Out:
# bool

# %%
student = "Kiran"

# %%
type(student)
# Out:
# str

# %%
height = 1.2

# %%
type(height)
# Out:
# float
