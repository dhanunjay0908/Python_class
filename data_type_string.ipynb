# %% [markdown]
# 1.	int (Integer): Represents whole numbers (positive, negative, or zero) without a fractional part. In Python 3, integers have arbitrary precision, meaning they can grow as large as your system's memory allows.

# %% [markdown]
# float (Floating-Point Number): Represents real numbers, including those with a fractional part indicated by a decimal point or scientific notation (e.g., 1.5e3 for 1500.0).

# %%
## to create file use .ipynb as extension

# %% [markdown]
# ### What is a String?
#
# - A string is a sequence of characters (letter, numbers, symbols, spaces) enclosed in quotes.
#
# - It's used to represent text data in python.

# %%
# How to create strings. 
# you can create string using single quotes, double quotes, and triple quotes.

# %%
# using single quotes 

name = 'Lohit'

message = "Hello world" 



print(type(name))
print(type(message))
# Out:
# <class 'str'>
# <class 'str'>

# %%
paragraph = '''this is a long paragraph
it can span multiple lines.
Very useful for long text'''

# %%
paragraph = """this is a long paragraph
it can span multiple lines.
Very useful for long text"""

# %%
print(paragraph)
# Out:
# this is a long paragraph
# it can span multiple lines.
# Very useful for long text

# %%
type(paragraph)
# Out:
# str

# %%
name
# Out:
# 'Lohit'

# %%
age = 10 
height = 1.2

# %%
# print()

type(name)
# Out:
# str

# %%
type(age)
# Out:
# int

# %%
type(height)
# Out:
# float

# %%
# single quote 

example1 = '"hello" world'

example2 = "Lohit's python class"

# %% [markdown]
# ## Using f-string (formatted strings)
#
# f-strings lets you embed variable inside a string easily.

# %%
name = "Lohit"

# %%
f"{name}'s python class"
# Out:
# "Lohit's python class"

# %%
age = 30

# %%
f"my name is lohit im {age} year old"
# Out:
# 'my name is lohit im 30 year old'

# %%
# Calculation inside string 

x = 10 
y = 5 

print(f"{x} + {y} = {x + y}")
# Out:
# 10 + 5 = 15

# %% [markdown]
# #### Key points for f-string
#
# - start the string with f".....", f'......',
#
# f""".....
# .....
# .... {variable1}
# ...  {variable2}
# """
#
# - use {} to insert variable or expression

# %% [markdown]
# ### Commmon operations and methods:
#
# String have a large number of build-in mehtod for manipulation string.

# %% [markdown]
# ## 1. Concatenation (+) and Repetition (*)
#
# - '+' : Joins two strings togethers, creating a new string.
# - '*' : Repeats a string a specified number of times(using an integer), creates new string.

# %%
institute = "Edukron"
focus_area = "Data Science"

# %%
institute + ' ' + focus_area
# Out:
# 'Edukron Data Science'

# %%
## Combining institue and focus area 

full_title = institute + " : " + focus_area
print(f"1. Full title: {full_title}")
full_title
# Out:
# 1. Full title: Edukron : Data Science
# 'Edukron : Data Science'

# %%
# "Welcome to Edurkon's 
institute = "Edukron"
course_name = "Data Engineer"

# "Welcome to Edukron's Data Engineer course!"
print("Welcome to Edukron's Data Engineer course!")
# Out:
# Welcome to Edukron's Data Engineer course!

# %%
print("Welcome to " +  institute + "'s " + course_name + " course!")
# Out:
# Welcome to Edukron's Data Engineer course!

# %%
print("Welcome to",  institute, course_name , "cource")
# Out:
# Welcome to Edukron Data Engineer cource

# %%
print("welcome to institute's" + ' ' "course_name")
# Out:
# welcome to institute's + ' ' course_name

# %%
# Repeating a separator 

separator = "-*=" * 50
separator
# Out:
# '-*=-*=-*=-*=-*=-*=-*=-*=-*=-*=-*=-*=-*=-*=-*=-*=-*=-*=-*=-*=-*=-*=-*=-*=-*=-*=-*=-*=-*=-*=-*=-*=-*=-*=-*=-*=-*=-*=-*=-*=-*=-*=-*=-*=-*=-*=-*=-*=-*=-*='

# %%
name = " python"

name * 5
# Out:
# ' python python python python python'

# %%
# concatenating multiple strings

part1 = "Learn "
part2 = "Data Engineering "
part3 = "Now! " * 3

call_to_action = part1 + part2 + part3
print(call_to_action)
# Out:
# Learn Data Engineering Now! Now! Now!

# %%
# A Python function is a reusable, named logic unit 
# that takes input, processes it, and optionally returns output.

# %% [markdown]
# ### Input()
#
# - fucntion is used to take data form the user at runtime through the keyboard
# - what ever you pass through this input() function its in the string datatype
#
#
# #### int()     # type casting
#  - it is used to convert any integer which is in the form of string
#
# #### float()     # type casting
#  - it is used to convert any float number which is in the form of string

# %%
name = "Lohit"

# %%
name
# Out:
# 'Lohit'

# %%
name = input("Enter your name")

# %%
type(name)
# Out:
# str

# %%
age = int(input("Enter your age"))

# %%
type(age)
# Out:
# int

# %%
number = int("123")
print(number)
type(number)
# Out:
# 123
# int

# %%
number = int(input("Enter any integer"))

# %%
number
# Out:
# 123

# %%
type(number)
# Out:
# int

# %%
int("1232345")
# Out:
# 1232345

# %%
float("123")
# Out:
# 123.0

# %%
height = float(input("enter your height"))

# %%
height
# Out:
# 1.2

# %%
type(height)
# Out:
# float

# %% [markdown]
# ### len()
#
# this is built in fucntion that returns the number of charaters (lenght) of a string.

# %%
institute = "   Edukron   "
course_slogan = "Learn Data Engineering with Real-Time Projects"
tech_stack = "Azure DevOps and Python"

# %%
# 1. lenght of the institute name 

name_length = len(institute)

# %%
name_length
# Out:
# 13

# %%
# lenght of course slogan

len(course_slogan)
# Out:
# 46

# %%
tech_stack = "Azure DevOps and Python"

len(tech_stack)
# Out:
# 23

# %%
lenght_tech_stack = len(tech_stack)

# %%
lenght_tech_stack
# Out:
# int

# %%
# lenght of empty string 

empty_len = ""
# type(empty_len)
len(empty_len)
# Out:
# 0

# %%
# length of a string with only spaces 

spaces = "    "
len(spaces)
# Out:
# 4

# %%
# lenght of string with number and symbols
complex_str = "Batch #101!"
len(complex_str)
# Out:
# 11

# %%
lenght_complex_string = len(complex_str)
print(lenght_complex_string)
# Out:
# 11

# %%
lenght_complex_string
# Out:
# 11

# %%
lenght_complex_string
# Out:
# 11

# %%
institute = "Edukron"
course_slogan = "Learn Data Engineering with Real-Time Projects"
tech_stack = "Azure DevOps and Python"

# %%
print(len(institute))
print(len(tech_stack))
# Out:
# 7
# 23

# %%
# lenght after concatination 

combined = institute + tech_stack
combined_len = len(combined)
print(combined_len)
# Out:
# 30

# %%
len(".     poaierpofiahe")
# Out:
# 19

# %% [markdown]
# #### Indexing ([]) and slicing ([:])
#
# - Indexing - Accessing a single character at a specific position(index). Python 0-based indexing(first charater is at index 0)
# - Negative indcies count from the end(-1 is the last charater)

# %%
tech_stack = "Azure DevOps and Python"

# %%
name = "Python"

# %%
name[5]
# Out:
# 'n'

# %%
name[-1]
# Out:
# 'n'

# %%
name[-4]
# Out:
# 't'

# %%
"P   y  t  h  o  n"
[0,  1, 2, 3, 4, 5]
[-6,-5,-4,-3,-2,-1]

# %%
tech_stack = "Azure DevOps and Python"

# %%
# accesing 'r'
tech_stack[3]
# Out:
# 'r'

# %%
# accessing 'n'
tech_stack[-1]
# Out:
# 'n'

# %%
# accessing 'P'
tech_stack[-6]
# Out:
# 'P'

# %% [markdown]
# ### slicing[start:stop:step]:
# - Extracting portion(substring) of the string using [start:stop:step]
#
#     - **start** : The index where the slice begins (inclusive). Default to 0
#     - **stop** : The index where the slice ends (exclusive). Defaults to the end of the string.\
#     - step : The increment between indices. Defaults to 1.

# %%
len(tech_stack)
# Out:
# 23

# %%
tech_stack = "Azure    DevOps and Python"
tech_stack[:10]
# Out:
# 'Azure    D'

# %%
# get the the first 5 chars of tech_stack "Azure"

first_5 = tech_stack[0:5]
first_5
# Out:
# 'Azure'

# %%
first_4 = tech_stack[:5]
first_4
# Out:
# 'Azure'

# %%
tech_stack[4]
# Out:
# 'e'

# %%
"A  z  u  r  e"
[0, 1, 2, 3, 4, 5]

# %%
tech_stack = "Azure DevOps and Python"

# output = "ure"
tech_stack[2:]
# Out:
# 'ure DevOps and Python'

# %%
tech_stack[:]           # [0:"last char"]
# Out:
# 'Azure DevOps and Python'

# %%
## get the substring "DevOps"
tech_stack = "Azure DevOps and Python"
devops_part = tech_stack[6:12]
devops_part
# Out:
# 'DevOps'

# %%
# get the last 6 chars ("Python")
tech_stack = "Azure DevOps and Python"
tech_stack[-6:]
# Out:
# 'Python'

# %%
tech_stack[-6:-1]
# Out:
# 'Pytho'

# %%
tech_stack = "Azure DevOps and Python"
# "zure DevOps and Pytho"
tech_stack[1:-1]
# Out:
# 'zure DevOps and Pytho'

# %%
institute
# Out:
# 'Edukron'

# %%
# skipping 1 char in between 
institute[::2]
# Out:
# 'Eurn'

# %%
# skipping 2 chars in between 
institute[::3]
# Out:
# 'Ekn'

# %%
institute
# Out:
# 'Edukron'

# %%
# Reverse the name using slicing
institute[::-1]
# Out:
# 'norkudE'

# %%
# string operation  (not with float or integer)
# string is immutable
# concatinate
# Repeate
# Indexing 
# Slicing


# String methods. str.lower() and str.upper()

# %% [markdown]
# ### str.lower()
#
# - **lower()**: Returns a new string with all characters converted to lowercase.
#
# - **upper()**: Returns a new string with all characters converted to uppercase.

# %%
print("string")
len("string")

# %%
institute = "Edukron"
focus_area = "Data Science"
tech_stack = "Azure DevOps and Python"

# %%
# institue in lowercase
print(institute)
institute.lower()
# Out:
# Edukron
# 'edukron'

# %%
# focus_area in uppercase()
print(focus_area)
focus_area.upper()
# Out:
# Data Science
# 'DATA SCIENCE'

# %%
gender1 = "male"
gender2 = "Male"
gender3 = "MALE"

# %%
print(gender1)
print(gender2.lower())
print(gender3.lower())
# Out:
# male
# male
# male

# %%
print(gender1.upper())
print(gender2.upper())
print(gender3)
# Out:
# MALE
# MALE
# MALE

# %%
tech_stack = "Azure DevOps and Python"

tech_stack.upper()
# Out:
# 'AZURE DEVOPS AND PYTHON'

# %%
# 5. Converting mixed case to uppercase
mixed_case = "PyThOn PrOjEcT"
mixed_case.upper()
# Out:
# 'PYTHON PROJECT'

# %%
# Applying to string with number/symbols (they remian unchanged)
code = "Batch-101-DS"
print(code.upper())
print(code.lower())
# Out:
# BATCH-101-DS
# batch-101-ds

# %%
code = "Batch-101#$$%^%^&*-DS"
print(code.upper())
print(code.lower())
# Out:
# BATCH-101#$$%^%^&*-DS
# batch-101#$$%^%^&*-ds

# %%
# chaining after concatenation 

full_title = institute + " : " + focus_area
print(full_title)
upper_title = full_title.upper()
print(upper_title)
lower_title = full_title.lower()
print(lower_title)
# Out:
# Edukron : Data Science
# EDUKRON : DATA SCIENCE
# edukron : data science

# %%
already_upper = "AZURE"
result = already_upper.upper()
result
# Out:
# 'AZURE'

# %%
full_title.upper()
upper(full_title)

len(full_title)
full_title.len()

# %% [markdown]
# ## str.strip(),str.lstrip(), str.rstrip()
#
# strip([chars]): Returns a new string with leading and trailing characters removed. If chars is omitted or None, it removes whitespace characters. If chars is given, it removes any character in the chars string from the ends.
#
# lstrip([chars]): Removes leading characters only.
#
# rstrip([chars]): Removes trailing characters only. Useful for cleaning up user input or data read from files.

# %%
name1 = " name "            # white
name2 = "name "
name3 = " name"
name4 = "name"
name5 = "name"

# %%
name4 == name5
# Out:
# True

# %%
gender = "male", "Male", "MALE".upper(), .lower()

# %%
# Removing leading/trailing whitespaces

user_input = "  Data Science  "
print(user_input)
cleaned_input = user_input.strip()

cleaned_input
# Out:
#   Data Science
# 'Data Science'

# %%
leading_space = "   Edukron"
print(leading_space)
left_stripped = leading_space.lstrip()
print(left_stripped)
# Out:
#    Edukron
# Edukron

# %%
trailing_space = "Python   "
print(trailing_space)
right_stripped = trailing_space.rstrip()
print(right_stripped)
# Out:
# Python
# Python

# %%
course_code = "===DS101==="
print(course_code)
cleaned_code = course_code.strip('=')
print(cleaned_code)
# Out:
# ===DS101===
# DS101

# %%
path = "/courses/Azure/"
print(path)
cleaned_path = path.strip("/")
cleaned_path
# Out:
# /courses/Azure/
# 'courses/Azure'

# %%
filename = "__init__.py"

filename.lstrip('_')
# Out:
# 'init__.py'

# %%
user_input = "  Data Science  "
print(user_input)
user_input.strip(' D')
# Out:
#   Data Science
# 'ata Science'

# %% [markdown]
# ### str.replace(old, new[count])

# %%
course_slogan = "Learn Data Engineering with Real-Time Projects"
tech_stack = "Azure DevOps and Python and SQL"

# %%
# replacing "data engineering" with "data scince"

new_slogan = course_slogan.replace('Data Engineering','Data Science')

print(course_slogan)
print(new_slogan)
# Out:
# Learn Data Engineering with Real-Time Projects
# Learn Data Science with Real-Time Projects

# %%
# reaplce spaces with underscores

slug = course_slogan.replace(" ", "_").lower() # Chain with lower()
slug
# Out:
# 'learn_data_engineering_with_real-time_projects'

# %%
tech_stack = "Azure DevOps and Python and SQL and and and"      # &
tech_stack.replace('and', '&')
# Out:
# 'Azure DevOps & Python & SQL & & &'

# %%
tech_stack = "Azure DevOps and Python and SQL and and and"
first_ampresand = tech_stack.replace("and", "&", 1)
first_ampresand
# Out:
# 'Azure DevOps & Python and SQL and and and'

# %%
course_slogan = "Learn Data Engineering with Real-Time Projects"
course_slogan.replace(' ','').lower()
# Out:
# 'learndataengineeringwithreal-timeprojects'

# %%
# case-sensitive replacement
text = "Python python pYthon"
text.replace("pYthon", "PYTHON")
# Out:
# 'Python python PYTHON'

# %% [markdown]
# interger, float, string, list
#
#  string operation  (not with float or integer)
#
# string is immutable
#
#  concatinate
#
#  Repeate
#
#  Indexing
#
#  Slicing
#
#
# String methods. str.lower() and str.upper()
#
# string.replace(old, new, count)
#
# string.split()

# %% [markdown]
# ## str.split(sep = None, maxsplit = 1)
#
# Explanation: Returns a list(it is kind of datatype) of substrings (words) by splitting the string at occurrences of the separator sep.
#
# If sep is omitted or None, splits by any whitespace character and discards empty strings.
# If sep is specified, splits exactly at that separator.
# maxsplit: If specified, performs at most maxsplit splits (resulting in maxsplit + 1 elements in the list). The remainder of the string is the last element. Examples

# %%
course_slogan = "Learn Data Engineering with Real-Time Projects"
tech_stack = "Azure DevOps,Python,SQL,Git"
institute = "Edukron"

# %%
# 2, splitting slogan by whitespace (default)

words = course_slogan.split()
print(words)
len(words)
# Out:
# ['Learn', 'Data', 'Engineering', 'with', 'Real-Time', 'Projects']
# 6

# %%
# splitting tech stack by comma
tech_stack = "Azure DevOps,Python,SQL,Git"
skills = tech_stack.split(',')     # by defualt itll take ' ' whitespace as default split criteria
print(skills)   
len(skills)
# Out:
# ['Azure DevOps', 'Python', 'SQL', 'Git']
# 4

# %%
# splitting institute name by character 'k'

institute = "Edukron"
parts = institute.split('k')
parts
# Out:
# ['Edu', 'ron']

# %%
# splitting slogan with maxsplit = 2

course_slogan = "Learn Data Engineering with Real-Time Projects"
split_limit = course_slogan.split(maxsplit=3)
print(split_limit)
len(split_limit)
# Out:
# ['Learn', 'Data', 'Engineering', 'with Real-Time Projects']
# 4

# %%
# splitting a string with multiple spaces 
multi_space = "Azure    DevOps  Python"
multi_space.split()
# Out:
# ['Azure', 'DevOps', 'Python']

# %%
file_path = "/Users/mac/Desktop/Python class/Python_2026_jan/data_type_string.ipynb"
splitted_file_path = file_path.split('/')
print(splitted_file_path)
print(type(splitted_file_path))
print(type(file_path))
# Out:
# ['', 'Users', 'mac', 'Desktop', 'Python class', 'Python_2026_jan', 'data_type_string.ipynb']
# <class 'list'>
# <class 'str'>

# %%
[1,2,3,"lohit", 1.5]    # elements in list are enclosed within []

# %%
# once you string using split() output is list

# str.join 

# this will take input as list and give output as string

# %% [markdown]
# ## str.join(iterable[list])
#
# Explanation: The opposite of split. Takes an iterable (like a list or tuple) of strings and concatenates its elements, using the string on which the method is called as the separator between elements.

# %%
course_list = ["Data Science", "Data Engineering", "Azure DevOps"]
tech_skills = ["Python", "SQL", "Git", "CI/CD"]
words = ['Learn', 'Data', 'Engineering']

# %%
single_string = "Data_Science Data_Engineering Azure_DevOps"
single_string.split()
# Out:
# ['Data_Science', 'Data_Engineering', 'Azure_DevOps']

# %%
# joiing course list with a comma and space

course_list = ["Data Science", "Data Engineering", "Azure DevOps"]
joined_courses = " ".join(course_list)
print(joined_courses)
# type(joined_courses)          # commenting
type(course_list)
# Out:
# Data Science Data Engineering Azure DevOps
# list

# %%
# joining tech skills with a hyphen

tech_skills = ["Python", "SQL", "Git", "CI/CD"]
joined_skills = "-".join(tech_skills)       # you can use any charater to join "k", "-", "@#"
print(joined_skills)
# Out:
# Python-SQL-Git-CI/CD

# %%
# joiing words back into a sentence with space
words = ['Learn', 'Data', 'Engineering']
sentence = " ".join(words)
print(sentence)
type(words)
type(sentence)
# Out:
# Learn Data Engineering
# str

# %% [markdown]
# ### i) str.startswith(prefix[, start[, end]]) and str.endswith(suffix[, start[, end]])
# Explanation:
#
# startswith(): Returns True if the string starts with the specified prefix, False otherwise.
#
#
# endswith(): Returns True if the string ends with the specified suffix, False otherwise.
# Optional start and end arguments restrict the check to a slice of the string.
# prefix/suffix can also be a tuple of strings to check against.

# %%
institute = "Edukron"
course_slogan = "Learn Data Engineering with Real-Time Projects"
filename = "edukron_report.pdf"

# %%
# check is institute startw with "Edu"
institute = "Edukron"
starts_edu = institute.startswith("Edu")
starts_edu
# Out:
# True

# %%
# check is institute startw with "Data"
institute = "Edukron"
starts_edu = institute.startswith("Data")
starts_edu
# Out:
# False

# %%
# check if slogan ends with "Projects"
course_slogan = "Learn Data Engineering with Real-Time Projects"
ends_projects = course_slogan.endswith("rojects")
print(ends_projects)
# Out:
# True

# %%
filename = "edukron_report.ipynb"

ends_pdf= filename.endswith(".ipynb")
ends_pdf
# Out:
# True

# %%
# check if filename ends with ".csv" or ".pdf"
filename = "edukron_report.pdf"
ends_data_format = filename.endswith((".pdf", '.csv'))
print(ends_data_format)
# Out:
# True

# %%
# check if slogan starts with "learn" or "explore"
course_slogan = "Learn Data Engineering with Real-Time Projects"
check_slogan = course_slogan.startswith(("Learn", "Explore", "Check if"))
print(check_slogan)
type(check_slogan)
# Out:
# True
# bool

# %%
# check a slice: does "Engineering" start at index 11 in slogan
course_slogan = "Learn Data Engineering with Real-Time Projects"
slice_check_start = course_slogan.startswith("Engineering", 11)
slice_check_start
# Out:
# True

# %%
# Check a slice: Does "Real-Time" end at index 36 in slogan?
# slice[start:end] inclused start, exludes end. so we cehck up to index 36 

slice_check_end = course_slogan.endswith("Real-Time", 0, 36)
print(slice_check_end)
# Out:
# False

# %% [markdown]
# ## j) str.find(sub[, start[, end]]) and str.index(sub[, start[, end]])
#
# Explanation:
#
# find(): Searches for the first occurrence of substring sub within the string (or the specified slice). Returns the starting index if found, and -1 if not found.
#
# index(): Same as find(), but raises a ValueError if the substring is not found. Use find() if you expect the substring might be missing and want to handle it gracefully (check for -1). Use index() if you expect the substring to be present and want an error if it's not.

# %%
course_slogan = "Learn Data Engineering with Real-Time Projects"
tech_stack = "Azure DevOps and Python"

# %%
# Find the index of "Data" in the slogan

data_pos = course_slogan.find("Engine")
data_pos
# Out:
# 11

# %%
course_slogan[6:11]
# Out:
# 'Data '

# %%
# find the index of "Python" in tech_stack
tech_stack = "Azure DevOps and Python Python"
python_pos = tech_stack.find("Python", 11, 36)
python_pos
# Out:
# 17

# %%
# find the index of "Java" in tech_stack        # returns -1 if not present
tech_stack = "Azure DevOps and Python Python"
print("testing code line 1")
print("testing code line 2")
print("testing code line 3")
Java_pos = tech_stack.find("Java")
print("testing code line 4")
print(Java_pos)
# Out:
# testing code line 1
# testing code line 2
# testing code line 3
# testing code line 4
# -1

# %%
# sing index to find "Azure"
tech_stack = "Azure DevOps and Python"

azure_pos = tech_stack.index("Azure")
azure_pos
# Out:
# 0

# %%
tech_stack = "Azure DevOps and Python Python"
print("testing code line 1")
print("testing code line 2")
print("testing code line 3")
Java_pos = tech_stack.find("Java")
print("testing code line 4")
print(Java_pos)
# Out:
# testing code line 1
# testing code line 2
# testing code line 3
# testing code line 4
# -1

# %%
# find substring that is not present in string 
tech_stack = "Azure DevOps and Python"
print("testing code line 1")
print("testing code line 2")
print("testing code line 3")
azure_pos = tech_stack.index("Java")
print("testing code line 4")
print(azure_pos)
# Out:
# testing code line 1
# testing code line 2
# testing code line 3
# ---------------------------------------------------------------------------
# ValueError                                Traceback (most recent call last)
# Cell In[119], line 6
#       4 print("testing code line 2")
#       5 print("testing code line 3")
# ----> 6 azure_pos = tech_stack.index("Java")
#       7 print("testing code line 4")
#       8 print(azure_pos)
#
# ValueError: substring not found

# %%
help(str)
# Out:
# Help on class str in module builtins:
#
# class str(object)
#  |  str(object='') -> str
#  |  str(bytes_or_buffer[, encoding[, errors]]) -> str
#  |
#  |  Create a new string object from the given object. If encoding or
#  |  errors is specified, then the object must expose a data buffer
#  |  that will be decoded using the given encoding and error handler.
#  |  Otherwise, returns the result of object.__str__() (if defined)
#  |  or repr(object).
#  |  encoding defaults to sys.getdefaultencoding().
#  |  errors defaults to 'strict'.
#  |
#  |  Methods defined here:
#  |
#  |  __add__(self, value, /)
#  |      Return self+value.
#  |
#  |  __contains__(self, key, /)
#  |      Return key in self.
#  |
#  |  __eq__(self, value, /)
#  |      Return self==value.
#  |
#  |  __format__(self, format_spec, /)
#  |      Return a formatted version of the string as described by format_spec.
#  |
#  |  __ge__(self, value, /)
#  |      Return self>=value.
#  |
# ...
